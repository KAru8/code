# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import category_encoders as ce
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn.feature_selection import f_classif # anova 
from sklearn.feature_selection import chi2 # хи-квадрат
from sklearn.ensemble import RandomForestRegressor # инструмент для создания и обучения модели  
from sklearn import metrics # инструменты для оценки точности модели
from sklearn import preprocessing

# %%
hotels = pd.read_csv('data\hotels.csv')
display(hotels.head())
display(hotels.info())
# Out:
#                                        hotel_address  \
# 0  Stratton Street Mayfair Westminster Borough Lo...
# 1  130 134 Southampton Row Camden London WC1B 5AF...
# 2   151 bis Rue de Rennes 6th arr 75006 Paris France
# 3  216 Avenue Jean Jaures 19th arr 75019 Paris Fr...
# 4          Molenwerf 1 1014 AG Amsterdam Netherlands
#
#    additional_number_of_scoring review_date  average_score  \
# 0                           581   2/19/2016            8.4
# 1                           299   1/12/2017            8.3
# 2                            32  10/18/2016            8.9
# 3                            34   9/22/2015            7.5
# 4                           914    3/5/2016            8.5
#
#                                   hotel_name reviewer_nationality  \
# 0                         The May Fair Hotel      United Kingdom
# 1            Mercure London Bloomsbury Hotel      United Kingdom
# 2          Legend Saint Germain by Elegancia               China
# 3  Mercure Paris 19 Philharmonie La Villette      United Kingdom
# 4                Golden Tulip Amsterdam West              Poland
#
#        negative_review  review_total_negative_word_counts  \
# 0             Leaving                                   3
# 1       poor breakfast                                  3
# 2   No kettle in room                                   6
# 3          No Negative                                  0
# 4         Torn sheets                                   4
#
#    total_number_of_reviews                                    positive_review  \
# 0                     1994                                 Staff were amazing
# 1                     1361                                           location
# 2                      406                                        No Positive
# 3                      607   Friendly staff quiet comfortable room spotles...
# 4                     7586   The staff was very friendly and helpful Break...
#
#    review_total_positive_word_counts  \
# 0                                  4
# 1                                  2
# 2                                  0
# 3                                 11
# 4                                 20
#
#    total_number_of_reviews_reviewer_has_given  reviewer_score  \
# 0                                           7            10.0
# 1                                          14             6.3
# 2                                          14             7.5
# 3                                           8            10.0
# 4                                          10             9.6
#
#                                                 tags days_since_review  \
# 0  [' Leisure trip ', ' Couple ', ' Studio Suite ...           531 day
# 1  [' Business trip ', ' Couple ', ' Standard Dou...           203 day
# 2  [' Leisure trip ', ' Solo traveler ', ' Modern...           289 day
# 3  [' Leisure trip ', ' Solo traveler ', ' Standa...           681 day
# 4  [' Business trip ', ' Couple ', ' Standard Dou...           516 day
#
#          lat       lng
# 0  51.507894 -0.143671
# 1  51.521009 -0.123097
# 2  48.845377  2.325643
# 3  48.888697  2.394540
# 4  52.385601  4.847060
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386803 entries, 0 to 386802
# Data columns (total 17 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   hotel_address                               386803 non-null  object
#  1   additional_number_of_scoring                386803 non-null  int64
#  2   review_date                                 386803 non-null  object
#  3   average_score                               386803 non-null  float64
#  4   hotel_name                                  386803 non-null  object
#  5   reviewer_nationality                        386803 non-null  object
#  6   negative_review                             386803 non-null  object
#  7   review_total_negative_word_counts           386803 non-null  int64
#  8   total_number_of_reviews                     386803 non-null  int64
#  9   positive_review                             386803 non-null  object
#  10  review_total_positive_word_counts           386803 non-null  int64
#  11  total_number_of_reviews_reviewer_has_given  386803 non-null  int64
#  12  reviewer_score                              386803 non-null  float64
#  13  tags                                        386803 non-null  object
#  14  days_since_review                           386803 non-null  object
#  15  lat                                         384355 non-null  float64
#  16  lng                                         384355 non-null  float64
# dtypes: float64(4), int64(5), object(8)
# memory usage: 50.2+ MB
# None

# %% [markdown]
# ## 1. Работа со строковыми данными
#
# Поочередно рассмотрим строковые признаки, оценим возможность формриования нового признака для формирования модели

# %%
# Адреc отеля содержит сведения о стране, где расположен отель. с помощью функции split
# сформируем списки и возьмем последний элемент для формирования признака country. Новый
# признак пока тоже текстовый,  


hotels['hotel_address'] = hotels['hotel_address'].apply(lambda x: x.split(' '))
hotels['hotel_address'].head(10)
hotels['country'] = hotels['hotel_address'].apply(lambda x: x[-1])
hotels['country'].value_counts()
# Out:
# Kingdom        196774
# Spain           45132
# France          44830
# Netherlands     43006
# Austria         29178
# Italy           27883
# Name: country, dtype: int64

# %%
bin_encoder = ce.BinaryEncoder(cols=['country']) # указываем столбец для кодирования
country_bin = bin_encoder.fit_transform(hotels['country'])
hotels = pd.concat([hotels, country_bin], axis=1)
hotels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386803 entries, 0 to 386802
# Data columns (total 21 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   hotel_address                               386803 non-null  object
#  1   additional_number_of_scoring                386803 non-null  int64
#  2   review_date                                 386803 non-null  object
#  3   average_score                               386803 non-null  float64
#  4   hotel_name                                  386803 non-null  object
#  5   reviewer_nationality                        386803 non-null  object
#  6   negative_review                             386803 non-null  object
#  7   review_total_negative_word_counts           386803 non-null  int64
#  8   total_number_of_reviews                     386803 non-null  int64
#  9   positive_review                             386803 non-null  object
#  10  review_total_positive_word_counts           386803 non-null  int64
#  11  total_number_of_reviews_reviewer_has_given  386803 non-null  int64
#  12  reviewer_score                              386803 non-null  float64
#  13  tags                                        386803 non-null  object
#  14  days_since_review                           386803 non-null  object
#  15  lat                                         384355 non-null  float64
#  16  lng                                         384355 non-null  float64
#  17  country                                     386803 non-null  object
#  18  country_0                                   386803 non-null  int64
#  19  country_1                                   386803 non-null  int64
#  20  country_2                                   386803 non-null  int64
# dtypes: float64(4), int64(8), object(9)
# memory usage: 62.0+ MB

# %%
# в датасете 1492 уникальных отеля, количество упоминаний одного отеля не превышает 1%.
# Кодирование данного признака приведет к формированию большого окличества новых признаков,
# что сделает модель сложной. Данный признак на данном этапе подлежит исключению
hotels['hotel_name'].value_counts()
hotels.drop(columns=['hotel_name', 'country', 'hotel_address'], axis=1, inplace=True)

# %%
# Уменьшим количество значений признака страны рецензента - объединим страны, упоминающиеся менее 2000 раз, в категорию другие 

nation_counts = hotels['reviewer_nationality'].value_counts()
nation_list = nation_counts[nation_counts <= 2000].index.tolist()
  
hotels['reviewer_nationality'] = hotels['reviewer_nationality'].apply(lambda x: 'Other' if x in nation_list else x)

# %%
bin_encoder_2 = ce.BinaryEncoder(cols=['reviewer_nationality']) # указываем столбец для кодирования
country_bin = bin_encoder_2.fit_transform(hotels['reviewer_nationality'])
hotels = pd.concat([hotels, country_bin], axis=1)
hotels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386803 entries, 0 to 386802
# Data columns (total 23 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   additional_number_of_scoring                386803 non-null  int64
#  1   review_date                                 386803 non-null  object
#  2   average_score                               386803 non-null  float64
#  3   reviewer_nationality                        386803 non-null  object
#  4   negative_review                             386803 non-null  object
#  5   review_total_negative_word_counts           386803 non-null  int64
#  6   total_number_of_reviews                     386803 non-null  int64
#  7   positive_review                             386803 non-null  object
#  8   review_total_positive_word_counts           386803 non-null  int64
#  9   total_number_of_reviews_reviewer_has_given  386803 non-null  int64
#  10  reviewer_score                              386803 non-null  float64
#  11  tags                                        386803 non-null  object
#  12  days_since_review                           386803 non-null  object
#  13  lat                                         384355 non-null  float64
#  14  lng                                         384355 non-null  float64
#  15  country_0                                   386803 non-null  int64
#  16  country_1                                   386803 non-null  int64
#  17  country_2                                   386803 non-null  int64
#  18  reviewer_nationality_0                      386803 non-null  int64
#  19  reviewer_nationality_1                      386803 non-null  int64
#  20  reviewer_nationality_2                      386803 non-null  int64
#  21  reviewer_nationality_3                      386803 non-null  int64
#  22  reviewer_nationality_4                      386803 non-null  int64
# dtypes: float64(4), int64(13), object(6)
# memory usage: 67.9+ MB

# %%
# Наличие/отсутствие негативного отзыва
hotels[hotels['negative_review'] == 'No Negative'].shape[0]
hotels['is_negative'] = hotels['negative_review'].apply(lambda x: 0 if x == 'No Negative' else 1)

# %%
# Наличи/отсутствие положительного отзыва
hotels[hotels['positive_review'] == 'No Positive'].shape[0]
hotels['is_positive'] = hotels['positive_review'].apply(lambda x: 0 if x == 'No Positive' else 1)

# %%
hotels.drop(columns=['reviewer_nationality', 'negative_review', 'positive_review'], axis=1, inplace=True)

# %%
hotels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386803 entries, 0 to 386802
# Data columns (total 22 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   additional_number_of_scoring                386803 non-null  int64
#  1   review_date                                 386803 non-null  object
#  2   average_score                               386803 non-null  float64
#  3   review_total_negative_word_counts           386803 non-null  int64
#  4   total_number_of_reviews                     386803 non-null  int64
#  5   review_total_positive_word_counts           386803 non-null  int64
#  6   total_number_of_reviews_reviewer_has_given  386803 non-null  int64
#  7   reviewer_score                              386803 non-null  float64
#  8   tags                                        386803 non-null  object
#  9   days_since_review                           386803 non-null  object
#  10  lat                                         384355 non-null  float64
#  11  lng                                         384355 non-null  float64
#  12  country_0                                   386803 non-null  int64
#  13  country_1                                   386803 non-null  int64
#  14  country_2                                   386803 non-null  int64
#  15  reviewer_nationality_0                      386803 non-null  int64
#  16  reviewer_nationality_1                      386803 non-null  int64
#  17  reviewer_nationality_2                      386803 non-null  int64
#  18  reviewer_nationality_3                      386803 non-null  int64
#  19  reviewer_nationality_4                      386803 non-null  int64
#  20  is_negative                                 386803 non-null  int64
#  21  is_positive                                 386803 non-null  int64
# dtypes: float64(4), int64(15), object(3)
# memory usage: 64.9+ MB

# %%
# Работа с датами. Можно по годам выделить
hotels['review_date'] = pd.to_datetime(hotels['review_date'])
hotels['year'] = hotels['review_date'].apply(lambda x: x.year)

# %%
bin_encoder_3 = ce.BinaryEncoder(cols=['year']) # указываем столбец для кодирования
country_bin = bin_encoder_3.fit_transform(hotels['year'])
hotels = pd.concat([hotels, country_bin], axis=1)
hotels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386803 entries, 0 to 386802
# Data columns (total 25 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   additional_number_of_scoring                386803 non-null  int64
#  1   review_date                                 386803 non-null  datetime64[ns]
#  2   average_score                               386803 non-null  float64
#  3   review_total_negative_word_counts           386803 non-null  int64
#  4   total_number_of_reviews                     386803 non-null  int64
#  5   review_total_positive_word_counts           386803 non-null  int64
#  6   total_number_of_reviews_reviewer_has_given  386803 non-null  int64
#  7   reviewer_score                              386803 non-null  float64
#  8   tags                                        386803 non-null  object
#  9   days_since_review                           386803 non-null  object
#  10  lat                                         384355 non-null  float64
#  11  lng                                         384355 non-null  float64
#  12  country_0                                   386803 non-null  int64
#  13  country_1                                   386803 non-null  int64
#  14  country_2                                   386803 non-null  int64
#  15  reviewer_nationality_0                      386803 non-null  int64
#  16  reviewer_nationality_1                      386803 non-null  int64
#  17  reviewer_nationality_2                      386803 non-null  int64
#  18  reviewer_nationality_3                      386803 non-null  int64
#  19  reviewer_nationality_4                      386803 non-null  int64
#  20  is_negative                                 386803 non-null  int64
#  21  is_positive                                 386803 non-null  int64
#  22  year                                        386803 non-null  int64
#  23  year_0                                      386803 non-null  int64
#  24  year_1                                      386803 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(18), object(2)
# memory usage: 73.8+ MB

# %%
def seasons(in_date):
    """make nunmber of season (1 - spring, 2 - summer, 3 - autumn, 4 - winter)

    Args:
        in_date (int64): number of month

    Returns:
        number of season, _type_: int64
    """
    if in_date in [3, 4, 5]:
        return 'spring'
    elif in_date in [6, 7, 8]:
        return 'summer'
    elif in_date in [9, 10, 11]:
        return 'autumn'
    else:
        return 'winter'
    hotels['season'] = hotels['month'].apply(seasons)

# %%
# работа с признаком tags. Соберем все тэги в словарь, где ключ - уникльный тэг,  значение - количество упоминания тэга
def tags_count(argum):
    """function for counting

    Args:
        argum (_type_): _description_
    """
    list = argum.strip("'[]").split(',')
    for i in range(len(list)):
        list[i] = list[i].strip("' ")
    #dict = {}
    #for element in list:
    #    if element not in dict.keys():
    #        dict[element] = 1
    #    else:
    #        dict[element] += 1
    return list

# %%
dict_tags = hotels['tags'].apply(tags_count)

# %%
dict_tags
# Out:
# 0         [Leisure trip, Couple, Studio Suite, Stayed 2 ...
# 1         [Business trip, Couple, Standard Double Room, ...
# 2         [Leisure trip, Solo traveler, Modern Double Ro...
# 3         [Leisure trip, Solo traveler, Standard Room wi...
# 4         [Business trip, Couple, Standard Double or Twi...
#                                 ...
# 386798    [Leisure trip, Group, Club Double or Twin Room...
# 386799    [Leisure trip, Couple, Standard Double Room, S...
# 386800    [Business trip, Solo traveler, Single Room, St...
# 386801    [Leisure trip, Solo traveler, Deluxe Double Ro...
# 386802    [Leisure trip, Couple, Bunk Bed Room, Stayed 4...
# Name: tags, Length: 386803, dtype: object

# %%
dict_count = {}

for di in dict_tags:
    for elem in di:
        if elem not in dict_count.keys():
            dict_count[elem] = 1
        else:
            dict_count[elem] += 1

dict_count
# Out:
# {'Leisure trip': 313593,
#  'Couple': 189212,
#  'Studio Suite': 543,
#  'Stayed 2 nights': 100263,
#  'Submitted from a mobile device': 230778,
#  'Business trip': 61989,
#  'Standard Double Room': 24151,
#  'Stayed 1 night': 145373,
#  'Solo traveler': 81235,
#  'Modern Double Room Echo': 4,
#  'Stayed 3 nights': 72000,
#  'Standard Room with 1 Double Bed': 677,
#  'Standard Double or Twin Room': 13062,
#  'Stayed 6 nights': 7399,
#  'Superior Twin Room': 4540,
#  'Double Room Non Smoking': 977,
#  'Superior Double Room': 23550,
#  'Stayed 4 nights': 35748,
#  'Double Room': 26386,
#  'Twin Hilton Guest Room': 711,
#  'Family with young children': 45836,
#  'Luxury Room': 233,
#  'Double or Twin Room Non Smoking': 394,
#  'Double or Twin Room': 16824,
#  'Standard Room': 3171,
#  'Group': 49088,
#  'Comfort Double or Twin Room': 1832,
#  'Standard': 934,
#  'Executive Double Room': 4763,
#  'Twin Room Non Smoking': 509,
#  'Studio Double Family': 395,
#  'Double Twin Superior Room': 21,
#  'X Ordinary Room': 66,
#  '2 rooms': 9287,
#  'King Deluxe Guest Room': 103,
#  'Double Studio': 204,
#  'Family with older children': 19802,
#  'Luxury Double Room': 824,
#  'Standard Double Room without Window': 1808,
#  'Hypoallergenic Double or Twin Room': 39,
#  'Premier Double Room': 765,
#  'Standard Room with Double Bed and Sofa Bed': 107,
#  'Basic Double Room': 2125,
#  'Classic Double Room': 12716,
#  'Deluxe King Room': 3993,
#  'Superior Family Room': 115,
#  'Stayed 5 nights': 15611,
#  'Double Guest Room': 2629,
#  'Standard Twin Room': 7325,
#  'Deluxe One Bedroom Apartment': 258,
#  'Travelers with friends': 1630,
#  'Twin Room': 6279,
#  'Deluxe Double Room with Eiffel Tower view': 77,
#  'Standard King Room': 450,
#  'Studio': 728,
#  'Standard Double or Twin Room with Extra bed 2 Adults 1 Child': 68,
#  'Small Queen Room': 1890,
#  'Art King Room': 467,
#  'Triple Room': 3385,
#  'Superior Room': 3292,
#  'Superior Twin Room with Internal View': 518,
#  'Deluxe Twin Room': 2309,
#  'Executive Queen Room with Lounge Access': 139,
#  'Deluxe Double Room': 18623,
#  'Large Twin Room': 231,
#  'Executive King Room': 1962,
#  'Classic Double or Twin Room': 4576,
#  'Single Room': 7227,
#  'Superior Room with Spa access': 137,
#  'Luxury Suite Patio': 32,
#  'Premium Double or Twin Room with View': 25,
#  'Queen Guest Room': 2355,
#  'Chelsea Twin Suite': 57,
#  'Executive Suite': 149,
#  'Standard Room with 1 Single Bed': 268,
#  'Double Hilton Deluxe Room': 188,
#  'Superior Double or Twin Room with Parking': 14,
#  'Standard Queen Room': 2611,
#  'King Guest Room': 1202,
#  'Queen Hilton Guest Room': 221,
#  'Standard Double Room with Park View': 99,
#  'Classic Room': 3322,
#  'Executive Studio City View Family': 105,
#  'Deluxe Family Room': 115,
#  'Queen Room': 4071,
#  'City Twin Room': 379,
#  'Double Family Guestroom': 71,
#  'Stayed 8 nights': 1910,
#  'Deluxe Double with Terrace': 7,
#  'Queen Guestroom': 85,
#  'Club Double Room': 4485,
#  'Large Double Room': 867,
#  'River View Deluxe': 104,
#  'Superior Double Room Single use': 14,
#  'Deluxe Single Room': 2469,
#  'Standard Double Room with View Terrace': 113,
#  'Standard Single Room': 3470,
#  'Apartment for 3 to 4 People with Kitchenette': 27,
#  'Standard Triple Room': 1022,
#  'Deluxe Double or Twin Room': 4465,
#  'Double Room with Courtyard View': 442,
#  'Classic Single Room': 803,
#  'Superior Room with 1 Queen Bed': 131,
#  'Deluxe King or Twin Room': 1234,
#  'Stayed 7 nights': 5549,
#  'Superior King Room': 3208,
#  'Studio King': 161,
#  'Club Twin Room': 1039,
#  'Cosy Double Room': 1191,
#  'Double Room with Spa Bath': 288,
#  'Double Room with River View': 104,
#  'Deluxe Double Room with Two Double Beds': 252,
#  'Stayed 10 nights': 663,
#  'Stayed 14 nights': 184,
#  'King Room with River View': 45,
#  'Garden Twin Room': 21,
#  'Double Hilton Guestroom': 1001,
#  'Double Room Disability Access': 129,
#  'Superior Double or Twin Room': 10238,
#  'Deluxe Double': 1232,
#  'Family Room': 1651,
#  'Compact Double Room': 685,
#  'Superior Premium Queen Room': 33,
#  'Superior Room for 1 2 people with Kitchenette': 11,
#  'Classic Double Room Loge Classique': 61,
#  'Superior Room with 1 Double bed and Sofa 3 adults': 26,
#  'City King Room': 551,
#  'Superior Queen Room': 3686,
#  'Pasha Suite': 13,
#  'Deluxe Double Room Annex': 50,
#  'Double Room with Extra Bed 2 Adults 1 Child': 20,
#  'Twin Guest Room': 1643,
#  'Double Room with Two Double Beds': 816,
#  'Junior Suite': 3392,
#  'Double or Twin Ground Floor': 270,
#  'Modern Double Room Narcisse': 4,
#  'Superior Room with Queensize Bed and double couch 2 adults 2 children': 193,
#  'King Hilton Guest Room': 490,
#  'Quadruple Room': 873,
#  'Junior Suite Twin 1 2 Adults': 6,
#  'Double Room Medium': 54,
#  'Executive room with Executive lounge access Free Wifi': 15,
#  'Double Room 1 Adult': 483,
#  'Double Room with City View': 251,
#  'Urban Double or Twin Room': 147,
#  'Superior King or Twin Room': 1331,
#  'Dorsett Double Room': 787,
#  'Suite with Spa Access': 2,
#  'Deluxe Double Room with Private Access to Pool and Spa': 63,
#  'Privilege Junior Suite with Spa Access': 16,
#  'Deluxe Double Room 1 2 Adults': 225,
#  'Special Offer Superior Double Room': 102,
#  'Classic Twin Room': 1798,
#  'Small Double Room': 2373,
#  '2 Connecting Rooms 5 people': 16,
#  'King Superior Room': 58,
#  'Double or Twin Room 1 2 Adults': 1812,
#  'Superior Double Double': 72,
#  'Twin Deluxe Room': 100,
#  'Two Connecting Double or Twin Rooms': 6,
#  'Deluxe Room': 2956,
#  'Double or Twin Room with Spa Access': 296,
#  'Classic Room with Courtyard View': 156,
#  'City Suite': 6,
#  'Suite with Balcony': 29,
#  'Business Double Room': 197,
#  'Standard Double Room with Sea View': 23,
#  'Suite': 1404,
#  'Deluxe Triple Room': 544,
#  'King Room': 2135,
#  'Superior Double or Twin Room 1 2 Adults': 723,
#  '3 rooms': 360,
#  'Room with Dock View Main Deck': 17,
#  'Superior Shard King': 308,
#  'Classic King Twin Room': 109,
#  'Duplex': 26,
#  'Deluxe Studio': 130,
#  'Classic Double Room with Garden View': 71,
#  'Superior Triple Room 3 Adults': 40,
#  'Family Room 2 Adults 1 Child': 100,
#  'Junior Suite with Spa Access': 102,
#  'River View Balcony Suite': 14,
#  'Superior Twin Room with View': 55,
#  'Standard Room with Spa access': 227,
#  'Economy Double Room': 880,
#  'Standard Room with Queen Bed': 231,
#  'Standard Double Twin Room': 1060,
#  'Superior': 209,
#  'Townhouse Deluxe': 11,
#  'Large Room': 171,
#  'Deluxe Queen Room': 566,
#  'Queen Guest Room with Sofa Bed': 200,
#  'Twin Hilton Deluxe': 32,
#  'Superior Double or Twin Room with Garden View': 10,
#  'Twin Room with Extra Bed 3 Adults': 24,
#  'Deluxe Room Barlow Wing': 446,
#  'Double Room with Mobile Phone': 16,
#  'One Bedroom Apartment': 264,
#  'Deluxe Double Studio': 111,
#  'One Bedroom Suite': 489,
#  'Superior Deluxe Room': 202,
#  'Executive Family Room': 231,
#  'Grand Deluxe Double or Twin Room': 124,
#  'Executive King Room Non Smoking': 72,
#  'Standard Double Room with Bridge View': 271,
#  'Classic King Room': 977,
#  'Queen or Two Double Beds Room': 549,
#  'Executive Twin Room': 825,
#  'Twin Deluxe Guest Room': 43,
#  'Stayed 19 nights': 23,
#  'Double Room with View': 478,
#  'Master Bedroom Suite': 15,
#  'Junior Double Room': 163,
#  'Room with Ramblas View': 107,
#  'Queen Room Mobility Access': 390,
#  'Luxury Double Room with Balcony': 14,
#  'Senior Suite 1 3 Adults': 3,
#  'Superior Room with Queen size bed and Sofa Bed': 205,
#  'Large Triple Room': 40,
#  'Studio Triple': 172,
#  'Deluxe King Room Wheelchair Accessible': 6,
#  'With a pet': 1045,
#  'Superior King': 52,
#  'Deluxe Double or Twin Room with Mountain View': 40,
#  'Studio King Family': 664,
#  'Twin Superior Room': 85,
#  'Club Room with Club Lounge Access': 13,
#  'Classic Double or Twin Room with Spa Access': 202,
#  'Standard Guest Room': 84,
#  'Standard Room with 2 Single Beds': 223,
#  'Comfort Twin Double Room': 231,
#  'Junior Double': 78,
#  'Comfort Double Room Courtyard Side': 32,
#  'Souterraine Double or Twin Room': 110,
#  'Classic Double or Twin Room with City View': 121,
#  'Economy Double or Twin Room': 50,
#  'Standard Double Room with Two Single Beds': 98,
#  'Double Deluxe Plus Room': 17,
#  'Standard Double': 547,
#  'Deluxe Double Room without Window': 28,
#  'King Room with Courtyard View': 33,
#  'Deluxe Double Room Pigalle 21': 2,
#  'Stayed 13 nights': 174,
#  'Superior Double or Twin Room with Balcony': 54,
#  'Junior King Suite': 45,
#  'Double Room with Balcony': 209,
#  'Stayed 9 nights': 966,
#  'Executive Family Room 2 Adults and 2 Children': 18,
#  'Deluxe Room with Two Double Beds': 97,
#  'Observatory King': 30,
#  'Small Double Room with Extra Bed Annex building': 14,
#  'Single Room with Shower': 135,
#  'King Guest Room Wheelchair Accessible': 46,
#  'Junior King Suite with Lounge Access': 4,
#  'Super Deluxe Double Room': 44,
#  'Double or Twin Room 2 Adults': 53,
#  'Deluxe King Room with River View': 414,
#  'Queen Bed Leisure': 91,
#  'Large King Room': 48,
#  'Executive King Room with Executive Lounge Access': 27,
#  'Comfort Double Room': 2005,
#  'Standard Compact Double Room': 24,
#  'Special Offer Executive Double Twin Room with Access to Nagomi Health': 52,
#  'Deluxe Duplex Room': 26,
#  'Design Double or Twin Room': 65,
#  'Deluxe Double or Twin Room 2 adults 1 child': 90,
#  'Two Bedroom Suite with Two Bathrooms': 19,
#  'Family Studio': 39,
#  'Deluxe Single Room with View': 76,
#  'Club King Room with Lounge Access': 16,
#  'Superior Room with Spa Fitness Access': 70,
#  'Classic Queen Room': 591,
#  'Family Room 2 Adults 2 Children': 699,
#  'Souterrain Comfort Room': 70,
#  'Superior Single Room': 846,
#  'Room Selected at Check In': 321,
#  'Executive Room with queen size bed and double sofa bed 2 adults 2 children': 30,
#  'Queen Double Room': 136,
#  'Classic Family Room': 48,
#  'Double Room with Sofa Bed': 358,
#  'Double or Twin Room with Extra Bed 3 Adults': 42,
#  'Two Bedroom Apartment': 133,
#  'Double Room Annex': 136,
#  'Superior Double Room with View': 76,
#  'Basic Single Room': 241,
#  'Economy Single Room': 104,
#  'Townhouse Club': 9,
#  'Club Room': 138,
#  'Quality Double or Twin Room': 176,
#  'Double Room with Single Bed': 251,
#  'Paseo de Gracia Double or Twin Room': 29,
#  'Superior Double Room with Sea View': 17,
#  'Executive Double or Twin Room': 1061,
#  'One Bedroom Queen Suite': 19,
#  'Classic Double or Twin Room 1 2 Adults': 99,
#  'Superior Double Room with Balcony and City View': 69,
#  'Two Connecting Rooms': 110,
#  'Queen Room Non Smoking': 526,
#  'Hilton Deluxe King Room': 45,
#  'Deluxe with Two Double Beds': 280,
#  'Royal Mews View King Room': 44,
#  'Luxury Quadruple Room': 17,
#  'Superior Twin Room Barlow Wing': 109,
#  'Superior Room with 2 Single Beds': 288,
#  'Junior Suite Avenue': 15,
#  'Classic Room with 2 double beds 2 Adults': 35,
#  'Superior Room with Double Bed and Sofa Bed': 67,
#  'Weekend Offer Standard Studio': 35,
#  'Superior Plus Twin Room': 61,
#  'King Double Room': 173,
#  'Premium Double Room': 449,
#  'Superior Double Room with Spa Access': 147,
#  'Double Room Courtyard': 6,
#  'Standard Quadruple Room': 204,
#  'Family Suite 2 Adults 2 Children': 71,
#  'Art Twin Room': 49,
#  'Double or Twin Room with Bathroom': 35,
#  'Special Offer Double Twin Room Stay and Park': 49,
#  'Standard Room 1 2 adults': 210,
#  'Economy Twin Room': 139,
#  'Double or Twin Room with View': 174,
#  'Family Room Two connecting Rooms': 15,
#  'Privilege Double Room': 175,
#  'Superior Double Room with Internal View': 821,
#  'Family Room with View': 19,
#  'Executive Club Room': 79,
#  'Large Penthouse Suite with Terrace and City View': 43,
#  'Camper Room': 173,
#  'Superior Double Room with City View': 222,
#  'Twin Room Disability Access': 112,
#  'Family Room with sofa bed': 127,
#  'Executive Room': 940,
#  'Duplex Double Room': 234,
#  'Corner Suite': 76,
#  'Superior Triple Room': 546,
#  'Spare Room Double': 36,
#  'Executive Double Room River View': 214,
#  'Deluxe King Room with Club Lounge Access': 39,
#  'Club Double or Twin Room': 83,
#  'Boudoir Double Room': 35,
#  'Maisonette': 82,
#  'Comfort Double Room With Sacr Coeur View': 15,
#  'Deluxe Double Room with View': 179,
#  'Budget Single Room Non Smoking': 20,
#  'Junior Suite Blue': 5,
#  'City Room': 112,
#  'Executive Queen Room with Sofa': 68,
#  'Premium Twin Room': 18,
#  'Premium Double or Twin Room': 526,
#  'Double Suite': 146,
#  'King Hilton Plaza Room': 41,
#  'Premier King Room with City View': 138,
#  'Superior Double or Twin Room with Terrace': 179,
#  'Dalston King': 142,
#  'Double Room with Terrace': 285,
#  '2 Double Rooms next to each other': 3,
#  'Studio Double Room': 157,
#  'Family Duplex Room': 16,
#  'Executive Double Room with Spa Access': 41,
#  'Superior Double Room with Park View': 50,
#  'Standard Queen Room with Sofa Bed': 107,
#  'Deluxe Queen Guestroom': 18,
#  'Duplex King Suite 2 Adults 2 Children': 7,
#  'King Deluxe Room': 81,
#  'Stayed 17 nights': 27,
#  'Premium Superior Double Room': 18,
#  'Squint Penthouse Suite': 6,
#  'Superior Studio Apartment': 41,
#  'Penthouse Suite with Terrace and City View': 68,
#  'Deluxe Double Room Swimming Pool Hammam Access upon reservation': 3,
#  'Andaz Double Room': 75,
#  'Cozy Double or Twin Room': 83,
#  'Apartment 3 Adults': 23,
#  'Superior Queen Suite with Sofa Bed': 101,
#  'Queen or Twin Room': 56,
#  'Superior Room with a shower or a bath': 24,
#  'Superior Double Room with Balcony': 143,
#  'King Room with Balcony': 76,
#  'Comfort Single Room with Window and Double Bed': 14,
#  'Queen Room Disability Access Non Smoking': 30,
#  'Double Room 1 2 Adults': 393,
#  'Double or Twin Room with Balcony': 152,
#  'Executive Single Room': 156,
#  'Club Double or Twin Room with Club Lounge Access': 8,
#  'Triple Hilton Family Room': 76,
#  'Single Room Lower Ground Floor': 40,
#  'Superior Double Studio': 14,
#  'Two Adjacent Classic Rooms': 20,
#  'One Bedroom King Suite with Sofa Bed': 24,
#  'Stayed 11 nights': 306,
#  'Double Room L': 23,
#  'Comfort Double or Twin Room 1 2 Adults': 100,
#  'Standard Triple Room with Queen Bed and Sofa Bed': 14,
#  'Camper Suite': 28,
#  'Garden King Room': 73,
#  'Privilege Room with 1 Kingsize Bed': 34,
#  'Comfort Room': 544,
#  'Accessible Queen Guest Room': 80,
#  'Superior Double Room Disability Access': 300,
#  'Classic Twin Room with Garden View': 48,
#  'Deluxe Designer': 8,
#  'Deluxe Junior Suite': 112,
#  'Superior Double Room with free unlimited WIFI': 84,
#  'Luxury Room 2 Adults with canal view': 14,
#  'Standard Room Sopi': 38,
#  'Executive Double Room with Whirlpool': 85,
#  'Junior Suite with Bath': 4,
#  'Deluxe Double Room with Extra Bed': 13,
#  'Cosy Single Room': 356,
#  'Amsterdam Street Art Queen Guest Room': 10,
#  'Tiny Single Room': 36,
#  'Queen Room with Sofa Bed': 116,
#  'Deluxe Club Double Room': 41,
#  'Family Junior Suite 3 Adults 1 Child': 116,
#  'Deluxe King Room with Paris View': 10,
#  'Superior Room with 1 Double Bed and 1 Sofa Bed 2 places': 10,
#  'Executive Double Room with Turkish Bath': 8,
#  'Executive Room with Two Double Beds': 26,
#  'Triple Room 2 Adults 1 Child': 168,
#  'Deluxe King Room with Stadium View': 279,
#  'Double Deluxe Room': 290,
#  'Superior Quadruple Room With Balcony': 35,
#  'Club Single Room': 278,
#  'Luxury Suite with whirlpool': 24,
#  'Small Single Room': 233,
#  'Standard Studio': 68,
#  'Premier King Room Barlow Wing': 60,
#  'City King or Twin Room': 676,
#  'Twin Room with Free Airport Shuttle Service from 5 00am to 00 30am': 54,
#  'King Room with City View Top floors': 5,
#  'Classic Triple Room': 204,
#  'Superior Queen Room with Double Sofa': 54,
#  'Classic Room with Queen Bed': 71,
#  'Small Single Room with Balcony': 41,
#  'Two Bedroom Suite': 69,
#  'Executive Deluxe Studio Suite': 42,
#  'Triple Family Guestroom': 81,
#  'Deluxe Suite': 122,
#  'Deluxe Double or Twin Room with Canal View': 226,
#  'Double Room with Street View': 193,
#  'Superior Double Room with Terrace and Private Pool': 33,
#  'Standard Double or Twin Room 1 2 Adults': 55,
#  'Loft': 39,
#  'Deluxe Double or Twin Room 1 2 Adults': 109,
#  'Deluxe Family Room with 1 Double and 2 Single Beds 4 Adults': 22,
#  'Club Level Classic Rooms': 6,
#  'Superior King Room with River View': 34,
#  'Queen Room Upper Floors': 88,
#  'Privilege Superior Room': 9,
#  'Double Room Disability Access Non Smoking': 31,
#  'Executive King Room with View': 13,
#  'Double or Twin Room 1 or 2 adults': 49,
#  'Classic Triple Room 3 Adults': 64,
#  'Twin Room with View': 11,
#  'Superior Queen Room with Sofa': 131,
#  'Junior Suite 2 Adults': 143,
#  'Double Room with Sofa Bed Non Smoking': 224,
#  'Standard Room with Two Single Beds Renovated': 4,
#  'Superior Double Room Pigalle 17': 7,
#  'Executive Club Double Room': 111,
#  'Condal Double or Twin Room': 51,
#  'Twin Room with Mobile Phone': 6,
#  'Junior Suite with Private Access to Pool and Spa': 7,
#  'Queen Room with Mobility Access': 259,
#  'Panoramic Room': 21,
#  'Double or Twin Room with Extra Bed': 173,
#  'Queen Room with Sofa Bed Non Smoking': 43,
#  'Deluxe King Room with Balcony': 194,
#  'Standard Double Room No Window': 348,
#  'Double Room with Garden View': 71,
#  'Stayed 27 nights': 10,
#  'Double Room with Eiffel Tower View': 165,
#  'Double Room with City View 1 Adult': 13,
#  'Cabin Single Room': 154,
#  'Delightful Queen Room': 45,
#  'Superior Room with Queen Bed': 108,
#  'Club King Room': 109,
#  'Superior King Room Eiffel Tower View': 122,
#  'Double Room Free Wi Fi': 95,
#  'Large Comfort Double or Twin Room': 129,
#  'Superior Double or Twin Room with Extra Bed': 25,
#  'Double Room with Extra Bed': 150,
#  'Business Double or Twin Room': 321,
#  'Nhow Premium Double or Twin Room': 11,
#  'Deluxe King Room Balcony with Eiffel Tower View': 303,
#  'Twin Room with Courtyard View': 25,
#  'Standard Queen or Twin Room Lower Ground Floor': 44,
#  'Twin Room 1 2 people': 44,
#  'Superior Room with canal view': 51,
#  'Luxury Family Room': 64,
#  'Standard Quad Room': 27,
#  'Studio Room': 67,
#  'Special Offer Twin Double Room Stay and Park': 16,
#  'Single Hilton Guest Room': 30,
#  'Premium King Room': 26,
#  'Deluxe Queen Room with View': 42,
#  'Superior Room Non Smoking': 11,
#  'Double Room with French Bed': 61,
#  'Luxury King Room': 55,
#  'Family Apartment': 25,
#  'Double or Twin Room Allergy Free': 37,
#  'Double Room Lady Soul': 27,
#  'Superior Double Room with Private Patio': 49,
#  'Executive Premium Room with a Queen Bed': 44,
#  'Privilege Double Room 2 Adults 1 child': 40,
#  'Special Offer Double Room': 210,
#  'Deluxe King': 19,
#  'Special Offer Queen Room': 156,
#  'Superior Double or Twin Room with Sauna Access': 9,
#  'Loft Suite Disability Access': 6,
#  'Premier Twin Room': 96,
#  'Superior Double Twin Room': 225,
#  'Executive Double Room Eiffel Studio D Artiste with view of Paris': 28,
#  'Queen Deluxe Room': 59,
#  'Marina Double Suite': 81,
#  'Superior Double Room with 1 Double Bed and 1 Sofa Bed 2 places': 103,
#  'Double Room Baronne': 39,
#  'King Room with Sea View': 1,
#  'Executive Double or Twin Room with Harbour View': 31,
#  'Wonderful Room': 164,
#  'Superior Room with Two Double Beds and Balcony': 51,
#  'Comfort Single Room': 87,
#  'Deluxe King with Balcony': 170,
#  'Standard Room with Spa Access': 49,
#  'Romantic Special Offer': 41,
#  'Double or Twin Room with Courtyard View': 185,
#  'Deluxe Two Bedroom Suite': 3,
#  'Superior Studio': 57,
#  'Executive Studio': 122,
#  'Deluxe Twin Room 3 Adults': 5,
#  'Comfort Triple Room': 304,
#  'Deluxe Double and Single Room': 200,
#  'Standard Room with Queensize bed and Single Sofa Bed': 82,
#  'Discovery Double Room': 93,
#  'Studio Twin': 34,
#  'Superior Queen Room with Pool Access': 30,
#  'Classic Double or Twin Room with extra bed': 25,
#  'Junior Suite with Terrace': 41,
#  'Economy Double Room basement no window': 15,
#  'King Junior Suite City View with Access to Executive Lounge': 17,
#  'Business Single Room': 68,
#  'Deluxe King Room with Water View': 60,
#  'Deluxe Twin Room with City View': 41,
#  'Luxury Triple Room': 20,
#  'King Deluxe One Bedroom Suite with Lounge Access': 2,
#  'Double or Twin Room with City View': 192,
#  'Standard Twin Room with Sofa': 13,
#  'Deluxe Double Room with Spa Bath': 82,
#  'Junior Suite with Private Pool': 17,
#  'Executive Room with City View': 82,
#  'Superior Twin Room with Extra Bed': 45,
#  'Privilege Double Room with Saint Germain des Pr s Church View': 5,
#  'Deluxe Double or Twin Room with Opera View': 6,
#  'Special Offer Twin Room': 13,
#  'Attach Suite': 33,
#  'Four Seasons King Junior Suite': 4,
#  'Superior M Double Room': 78,
#  'Two Adjacent Double Rooms': 17,
#  'Superior Twin or Double Room': 57,
#  'Single Room with Bathroom': 8,
#  'Superior Double': 177,
#  'Comfort Twin Room': 127,
#  'Superior Double Room with Terrace': 198,
#  'Superior Junior Suite': 33,
#  'Double or Twin Room 1 Adult': 31,
#  'Economy Plus Double Room': 16,
#  'Superior Deluxe Double Room': 18,
#  'Economy Single Room basement no window': 22,
#  'Double Room 2 Adults': 133,
#  'Small Double Room Annex building': 56,
#  'Family Suite': 152,
#  'Junior Suite 2 Adults 1 Child': 4,
#  'Executive Junior Suite': 47,
#  'Superior Room with Queen Bed Sofa': 172,
#  'Deluxe King Guestroom': 17,
#  'Quadruple Apartment': 2,
#  'Executive Double Room with Executive Lounge Access': 15,
#  'Queen Guest Room with River View': 62,
#  'Standard Family Room': 177,
#  'Luxury Four Poster': 73,
#  'Superior Deluxe Double or Twin Room': 58,
#  'Deluxe Double Room with Club Lounge Access': 6,
#  'Secret Double Room': 68,
#  'Prestige Family Room': 15,
#  'Classic Guest room 1 King or 2 Twin Single Bed s': 82,
#  'King Deluxe Room with Canal View': 26,
#  'Superior Room with 1 Double Bed and 1 Sofa Bed 1 place': 19,
#  'Cool Corner Suite': 17,
#  'Deluxe Queen Room with River View': 90,
#  'Souterrain Double Room': 96,
#  'Executive King Room with Lounge Access': 452,
#  'Standard Double or Twin with view': 23,
#  'Luxury King Room with River View': 18,
#  'Standard Double Room with Tea Time Included': 43,
#  'Business Double Room with Courtyard View and Public Transport Ticket': 19,
#  'Queen Hilton Superior Room': 118,
#  'Executive Double Room with Lounge Access': 45,
#  'Royal Mews View Classic Double': 66,
#  'Comfort Double Room with Extra Bed': 36,
#  'Premier Twin Room with City View': 22,
#  'Superior Room with Extra Bed 3 Adults': 8,
#  'Comfort Double or Twin Room with Extra Bed': 45,
#  'Mini Room': 84,
#  'Superior King Room Barlow Wing': 169,
#  'Comfort Double or Twin Room with Rambla View': 22,
#  'Art Deco Deluxe Room View and Terrace': 2,
#  'Standard Double or Twin Room with Balcony': 168,
#  'Double or Twin Room with Sea View': 128,
#  'Hoxton Studio Suite': 15,
#  'Family Room with King Bed': 53,
#  'Compact Double Room with Private Bathroom': 100,
#  'Executive Queen Room': 78,
#  'Elegance Double or Twin Room': 21,
#  'King Double or Twin Room': 173,
#  'Classique Double Room': 60,
#  'Deluxe Twin Room Balcony with Eiffel Tower View': 43,
#  'Twin Room with City View 1 2 Adults': 28,
#  'Deluxe Studio Suite': 75,
#  'King Corner Room': 27,
#  'Superior Room with Queensize Bed and Single Sofa Bed 2 Adults 1 Child': 47,
#  'Wonderful Double or Twin Room': 214,
#  'Queensgate Double Room': 27,
#  'Executive Master Suite': 2,
#  'Duplex Room': 90,
#  'Grande Suite': 26,
#  'Double Superior Room': 34,
#  'Art Room with Iconic View': 74,
#  'Classic Room with 1 Queen bed': 30,
#  'Double or Twin Room with Extra Bed 3 Adults with Free Airport Shuttle Service from 5 00am to 00 30am': 45,
#  'Superior Queen Suite with Sofa': 52,
#  'Deluxe Double with Winter Garden View': 41,
#  'King Deluxe Family Room': 7,
#  'Business Double Room with 500 Frequent Flyer Miles': 4,
#  'Superior Double Room with Queen size bed': 71,
#  'Double Room Ground Floor': 12,
#  'Junior Triple Room': 69,
#  'Penthouse': 1,
#  'Intuition Room': 29,
#  'Tradition Double Room': 63,
#  'Executive Queen Room with Two Queen Beds with lounge Access': 24,
#  'Deluxe Barcelona city View': 23,
#  'Twin Room with Public Transport Ticket': 73,
#  'Double Room with City View 1 2 Adults': 15,
#  'Eiffel Tower View Twin Room': 34,
#  'Executive King or Twin Room with Lounge Access and Park View': 7,
#  'Small Double or Twin Room': 82,
#  'Loft Suite': 27,
#  'Twin Room with Spa Bath': 84,
#  'Superior Double or Twin Room with Spa Access': 73,
#  'Deluxe Double Room with State Opera View': 93,
#  'Two Connecting Double Rooms': 123,
#  'Standard Double Room with View': 68,
#  'Double Room Crash Pad Under 30s': 24,
#  'Superior Room with 1 Double Bed': 65,
#  'Family Room 3 Adults': 140,
#  'Executive Studio City View': 81,
#  'Special Room': 79,
#  'Privilege King Room': 64,
#  'Twin Room with Extra Bed': 44,
#  'Double Deluxe room with Roman Bath': 12,
#  'Executive Triple Room': 103,
#  'Quality Single Room': 74,
#  'Standard Room with One Double Bed and Single Sofa Bed': 65,
#  'Superior Family Room 2 Adults 1 Child': 65,
#  'Queen Room with Balcony': 14,
#  'King Room Non Smoking': 103,
#  'Royal Duplex Suite': 4,
#  'Art Deco Double Room': 16,
#  'Deluxe Double or Twin Room with Terrace': 67,
#  'Double or Twin Room with Pool View': 5,
#  'Double or Twin Room with Extra Bed with Balcony': 55,
#  'Superior Plus Double Room': 94,
#  'Superior Premium Room with Queen Bed and Sofa Bed': 15,
#  'Deluxe Double Room with Separate Lounge Area': 11,
#  'Grand Deluxe Room': 26,
#  'Privilege Room': 56,
#  'Loft Junior Suite': 8,
#  'Royal Suite with Canal View': 41,
#  'King Hilton Guestroom': 67,
#  'Twin Room 1 2 Adults': 60,
#  'Eiffel Tower View King Room': 73,
#  '2 Connecting Rooms 4 Adults': 5,
#  'Mezzanine Suite': 16,
#  'Superior Queen Room with Single Sofa Bed': 68,
#  'Deluxe': 57,
#  'Double Room XL': 47,
#  'Luxury Room 3 Adults with canal view': 8,
#  'King Room with City View': 7,
#  'Family Room 4 guest': 77,
#  'Grand Premier King Room': 3,
#  'Superior Room with 1 kingsize bed': 94,
#  'Single Hilton Guestroom': 54,
#  'Classic Double Room with Breakfast': 57,
#  'King Executive Room with Lounge Access': 88,
#  'Family Room with Spa access': 65,
#  'King or Twin Room with River View': 33,
#  'Imperial Club Double Room with access to the Club Lounge': 21,
#  'Panorama Double Room': 42,
#  'Stayed 12 nights': 217,
#  'Luxury Suite': 224,
#  'Double or Twin Room with Terrace': 185,
#  'Stayed 15 nights': 87,
#  'Stayed 21 nights': 19,
#  'Comfort Double or Twin Room Non Smoking': 92,
#  'Standard Double or Twin Room with Balcony 1 Adult': 50,
#  'Royal Room with Ramblas view': 45,
#  'Premium Double or Twin Room XL': 36,
#  'Classic Double or Single Room': 97,
#  'Special Offer Double or Twin Room': 85,
#  'Deluxe Double Twin Room': 58,
#  'Duplex Suite': 79,
#  'Standard Twin Room with Tea Time Included': 10,
#  'Double Room with Shower': 19,
#  'Duplex Junior Suite with Spa access': 74,
#  'Comfort Quadruple Room': 48,
#  'Apartment 6 Adults': 11,
#  'Superior Plus Room': 41,
#  'Ruyschen Suite': 8,
#  'Deluxe Two Bedroom Apartment': 20,
#  'Deluxe Double Room with Patio': 11,
#  'penta Plus Room': 25,
#  'Classic Cosy Room': 35,
#  'Single Room Joy': 10,
#  'Superior Double Room Loge Sup rieure': 41,
#  'Large Double or Twin Room': 8,
#  'Basic Double': 51,
#  'Deluxe Studio Apartment 2 Adults': 9,
#  'Park King': 41,
#  'Executive Room Queen size Bed': 6,
#  'Apartment': 99,
#  'Duplex Junior Suite': 16,
#  'Stayed 18 nights': 24,
#  'Superior Studio with City View': 115,
#  'Superior Double or Twin Room with View': 216,
#  'Deluxe Guest Room': 143,
#  'Superior Queen Room with 2 Single Sofa Beds': 58,
#  'Sextuple Room': 23,
#  'Deluxe Double Room with Bath': 39,
#  'Privilege Junior Suite with Terrace and Spa Access': 10,
#  'Double Room Curieuse': 87,
#  'Deluxe Twin Room Annex': 8,
#  'Two Adjoining Superior Suite': 33,
#  'Privilege Room with 1 Queen Size bed': 6,
#  '2 Adjacent Non Communicating Rooms': 20,
#  'Corner Double Room': 22,
#  'Deluxe One Bedroom Suite': 102,
#  'Double Room Single Use': 41,
#  'Superior Suite with 1 Double Bed and 1 Single Bed': 143,
#  'Superior Double Room with Free Access to Steam Bath': 42,
#  'Duplex Suite with Sofa Bed': 3,
#  'Standard Double Room with Parking': 16,
#  'Executive Double Room with City View': 18,
#  'Amiral Single Room': 20,
#  'One Bed Feature Room': 57,
#  'Executive Double Room with Air Conditioning': 74,
#  'Standard Room for 1 or 2 people with Kitchenette': 91,
#  'Superior Triple Room XL': 24,
#  'Two Connecting Double Rooms 5 adults': 6,
#  'Queen Room with Two Queen Beds 4 Adults': 42,
#  'Double Room with Private Bathroom': 61,
#  'Triple Studio': 49,
#  'King Hilton Waterfront': 40,
#  'Twin Premier Room': 3,
#  'Double Executive Room': 8,
#  'Double or Twin Room with Balcony or Terrace': 6,
#  'Junior Suite with River View and Balcony': 33,
#  'Superior Double Room with Sofa Bed': 27,
#  'Junior Suite with Executive Lounge Access': 26,
#  'Single Guest Room': 78,
#  'Superior Double Room with Duomo View': 15,
#  'King Size Double Room': 18,
#  'Deluxe Double or Twin Room 3 Adults': 16,
#  'Family Quadruple Room': 44,
#  'Two Connecting Rooms with Free Access to Hamman': 5,
#  'Deluxe Double Room with River View': 100,
#  'Standard Apartment': 69,
#  'Queen Superior Room': 36,
#  'Exclusive Guest room 1 King or 2 Twin Single Bed s': 8,
#  'Park Suite': 5,
#  'Single Room Annex': 96,
#  'One Room Suite with Kitchenette': 99,
#  'Standard Room with 1 Double Bed and 1 Double Sofa bed': 27,
#  'Two Adjacent Rooms': 4,
#  'Superior Double or Twin Room XL with Extra Bed 2 Adults 1 Child': 1,
#  'Triple Room with Spa Bath': 35,
#  'Deluxe Room with view': 22,
#  'King Guestroom': 73,
#  'Executive Room 2 adults 2 children': 45,
#  'Single Room with Park View': 4,
#  'Deluxe Park View': 9,
#  'Twin Room with Private Bathroom': 27,
#  'Deluxe Double Room with Courtyard View': 24,
#  'Treat your Partner Package Double Room': 53,
#  'Superior Double or Twin Room XL': 73,
#  'Deluxe Double Room 1 2 adults': 57,
#  'Executive Room with River View': 19,
#  'Grand Suite': 28,
#  'Superior Double Room with Extra Bed': 5,
#  'Superior Room Swimming Pool Hammam Access upon reservation': 43,
#  'Garden View King': 24,
#  'Triple Room 3 Adults': 26,
#  'Double Room for Single Use': 20,
#  '4 rooms': 28,
#  'Business Apartment with Public Transport Ticket': 36,
#  'Junior Suite Canal View': 4,
#  'Standard Room with queen size bed and double sofa bed': 46,
#  'Family Room 4 Adults': 132,
#  'Junior Suite with City View': 20,
#  'Accessible Twin Guest Room': 14,
#  'Prestige Double Room': 164,
#  'Delightful King Twin Room': 21,
#  'Deluxe Double Room with City View': 92,
#  'Deluxe Queen Room with Balcony': 31,
#  'Accessible Twin Room': 38,
#  'Deluxe King Room with City View': 289,
#  'Privilege Room with a double bed upper floors': 99,
#  'Classic Double Room with View': 25,
#  'Executive Four Poster Room': 5,
#  'Suite 2 Adults': 16,
#  'Room with Dock View Upper Deck': 18,
#  'Double Room 1 Adult with Free Airport Shuttle Service from 5 00am to 00 30am': 39,
#  'Junior Suite with Spa Access Free Wifi': 18,
#  'Small Double Room without Window': 23,
#  'Double Room Attic': 65,
#  'Classic Junior Suite': 20,
#  'Superior Double or Twin Room with Landmark View': 43,
#  'Deluxe Guest room 1 King or 2 Twin Single Bed s': 15,
#  'Small Twin Room': 44,
#  'Luxury Two Bedroom Apartment': 6,
#  'Double or Twin Room with Bath': 35,
#  'Grand Junior Suite': 9,
#  'Deluxe Double Room with Garden View': 49,
#  'Standard Suite': 164,
#  'Executive Twin Room with Access to The Level Lounge': 5,
#  'Luxury Double Room Mezzanine': 41,
#  'Family room Free Wi Fi': 8,
#  'Superior King with Balcony': 20,
#  'Director s Double Room': 17,
#  'Executive Double Room with Square View': 2,
#  'Congress Suite': 10,
#  'Deluxe Double or Twin Room with City View': 119,
#  'King Grand Premier with Canal View': 7,
#  'Suite with Hot Tub': 55,
#  'King Room with Executive lounge access': 12,
#  'Deluxe Room with Courtyard View': 68,
#  'Double Room with Four Poster Bed': 22,
#  'Double Room with Public Transport Ticket': 163,
#  'Queen Hilton Deluxe': 42,
#  'Business Class Room': 69,
#  'Superior King Room with Sofa Bed': 133,
#  'Club Room with Club Lounge Access Free Wifi': 45,
#  'Superior Twin Room with Two Double Beds': 49,
#  'Superior room Design Style Free Wifi': 11,
#  'Double Room Atelier d Artiste with Spa Bath': 1,
#  'Junior Suite 1 2 Adults': 91,
#  'Privilege Room with Double Bed': 54,
#  'Deluxe Double Room with City View and Balcony': 32,
#  'King Cathedral View Room': 19,
#  'Room Assigned at Check in': 3,
#  'Four Poster Suite': 10,
#  'Executive King or Twin Room with Lounge Access': 38,
#  '2 Connecting Deluxe Rooms with VIP Service for Kids': 4,
#  'Stayed 16 nights': 38,
#  'Marvelous Suite Exchange': 3,
#  'Superior Double Room with Saint Germain des Pr s Church View': 27,
#  'Deluxe Family Room with View': 21,
#  'Superior Room 3 Adults': 7,
#  'Standard Double or Twin Room 3 Adults': 6,
#  'Family Communicating Rooms': 3,
#  'Canal View Superior Deluxe Room with Spa Bath': 30,
#  'Family Room Two Connecting Rooms': 41,
#  'King Accessible Superior Room': 26,
#  'Executive Double Room with Double Bed and Sofa Bed': 24,
#  'Kings Junior Suite': 42,
#  'Family Two Bedroom Suite': 24,
#  'Junior Alcove Suite with Access to Executive Lounge': 3,
#  'Exclusive Suite': 32,
#  'Superior Room with 1 Queensize Bed and Double Sofa bed': 40,
#  'Standard Twin Room with 2 single beds': 10,
#  'Superior Double or Twin Room Tea Time Wine Tasting Included': 15,
#  'Two Bedroom Family Joining Suite with Mobile Phone 2 adults 3 children': 7,
#  'Superior Suite 3 Adults': 2,
#  'Executive Double': 67,
#  'Andaz King Twin Room': 16,
#  'River Double Suite': 37,
#  'Executive Studio Suite': 113,
#  'Grand Deluxe Imperial Room': 7,
#  'Junior Suite 1 3 Adults': 14,
#  'Luxury Double Room Medium': 11,
#  'Executive Suite 2 Adults 2 Children': 16,
#  'Double or Twin Room with Terrace and Spa Access': 48,
#  'Executive Double Room with Two Double Beds with Lounge Access': 45,
#  'Family Room 2 Adults 2 Children with Access to Nagomi Health': 21,
#  'Standard Double or Twin Room Annex Building': 59,
#  'Junior Suite with Courtyard View': 11,
#  'Superior Guest room 1 King or 2 Twin Single Bed s': 37,
#  'Room with Park View': 7,
#  'Classic Studio': 42,
#  'Deluxe Garden Room': 32,
#  'Standard Room with 1 Double Bed and 1 Sofa Bed': 72,
#  'Deluxe Double Room with Terrace': 94,
#  'Garden View Twins': 9,
#  'Premier Room with Balcony': 62,
#  'Superior Room with Queensize Bed and Single Sofa Bed': 84,
#  'Superior Suite 2 Adults 2 Children': 32,
#  'Standard Twin Room with Bridge View': 132,
#  'Double Family Guest Room': 52,
#  'Junior King Suite with View 2 Adults': 13,
#  'Suite with Spa Access 3 Adults': 12,
#  'One Bedroom Suite with Lounge Access': 6,
#  'Classic Suite': 35,
#  'Executive King Room with Air Conditioning': 50,
#  'Junior Suite with Extra Bed': 28,
#  'Twin Deluxe with Canal View': 11,
#  'Double Room Crash Pad': 21,
#  'Panorama Suite': 22,
#  'Superior Room with Queen Bed and Sofa': 43,
#  'Triple Room Disability Access': 19,
#  'Standard Double Room with Queen Bed': 65,
#  'Deluxe Double Room with Terrace and Eiffel Tower View': 4,
#  'Penthouse Junior Suite with Access to Executive Lounge': 5,
#  'Suite with Rambla View': 5,
#  'Superior Double or Twin Room with Free Wifi': 83,
#  'Garden Room': 26,
#  'Double Room Relax': 12,
#  'Octagon Suite with Lounge Access': 1,
#  'Park Studio King': 16,
#  'Nadler Deluxe Double Room': 14,
#  'Deluxe Double or Twin Room with Sea View': 27,
#  'Park View Studio': 4,
#  'Double Executive Room with Lounge Access': 28,
#  'Deluxe Double or Twin Room with Parking': 3,
#  'Park Deluxe King': 30,
#  'Superior Double Room with Two Double Beds': 126,
#  'Deluxe Twin Room with View': 7,
#  'Double Room Trocad ro with Spa Bath': 10,
#  'Champagne Shopping package Double Room': 41,
#  'Superior Apartment 3 Adults': 4,
#  'Suite 2 Adults 1 Child': 6,
#  'Deluxe King Plus': 13,
#  'Single Room with Double Bed': 86,
#  'Economy Quadruple Room': 8,
#  'Double Room with Small Double Bed': 36,
#  'Deluxe Double or Twin Room with Canal View Annex building': 9,
#  'Classic Twin View': 16,
#  'Superior Double Room Breakfast included': 7,
#  'One Bedroom Suite with Kitchenette': 29,
#  'Wonderful Double Room': 14,
#  'Superior Twin Room with City View': 34,
#  'Special Offer Comfort Double Room with Breakfast and Parking Included': 3,
#  'Grand Executive Room': 1,
#  'Superior Room with 1 Queen Bed 1 Sofa Bed': 68,
#  'Premium Triple Room': 37,
#  'Chambers Junior Suite with Club Lounge Access': 35,
#  'Budget Single Room': 61,
#  'Double Room with Free Airport Shuttle Service from 5 00am to 00 30am': 56,
#  'Family Room with King Bed and Sofa Bed': 28,
#  'Executive King Room Non Smoking with Executive Lounge Access': 51,
#  'King Grand Premier Room': 38,
#  'Large Canal View King': 13,
#  'Business King Room': 11,
#  'Superior Double Room with Tea Time Included': 5,
#  '2 Twin Beds Guest Room': 6,
#  'Comfort Double or Twin Room with Balcony': 36,
#  'Residence Suite': 23,
#  'Family Premium Room 2 Adults 2 Children': 8,
#  'Grand Deluxe Contemporary Room': 11,
#  'Xscape King': 10,
#  'Classic Double Room with Private Terrace': 5,
#  'Single Room Non Smoking': 12,
#  'Studio 2 Adults': 29,
#  'Superior Suite with City View': 6,
#  'Garden View Queen': 12,
#  'Superior Premium Room with Queen Bed Sofa': 21,
#  'King Suite': 28,
#  'Executive Twin Room with Whirlpool': 6,
#  'Double Room Insolite': 40,
#  'Design Suite': 1,
#  'Duplex Suite with Spa Access': 34,
#  'Luxury Junior Suite': 44,
#  'Superior Double or Twin Room with Courtyard view': 18,
#  'Two Connecting Double and Twin rooms': 9,
#  'Deluxe Double Room with Spa Access': 32,
#  'Double Queen Waterfront': 80,
#  'Privilege Double Room with Eiffel Tower View': 32,
#  'Junior Suite with Balcony': 22,
#  'King Room with Sofa Bed and Balcony': 19,
#  'Executive Deluxe Room': 21,
#  'Standard Room with queen size bed and double sofa bed 3 Adults': 8,
#  'Fabulous Double or Twin Room': 78,
#  'Superior Double or Twin Room with Eiffel Tower partial view': 3,
#  'Superior Room with Spa Access Free Wifi': 7,
#  'Queen Suite with Balcony and City View': 5,
#  'Superior Room with View of Big Ben': 67,
#  'Premium Room 2 Adults': 16,
#  'Cozy Exchange King': 55,
#  'Deluxe Twin Room 2 Adults': 17,
#  'Standard Double Room Disability Access': 35,
#  'Deluxe Double Room 2 Adults 1 Child': 8,
#  'Hyatt King Room with View': 12,
#  ...}

# %%
hotels['Leisure trip'] = hotels['tags'].apply(lambda x: 1 if 'Leisure trip' in x else 0)
hotels['Couple'] = hotels['tags'].apply(lambda x: 1 if 'Couple' in x else 0)
hotels['Solo traveler'] = hotels['tags'].apply(lambda x: 1 if 'Solo traveler' in x else 0)
hotels['mobile submitted'] = hotels['tags'].apply(lambda x: 1 if 'Submitted from a mobile device' in x else 0)

# %%
def nights_col(ser):
    l = []
    for i in ser:
        if 'Stayed' in i:
            l.append(i)
    return str(''.join(l).strip('[]').split()).strip('[]').split()

# %%
def nights_cocol(ser):
    l = []
    for i in ser:
        if 'Stayed' or 'night' in i:
            ser.remove(i)
    return ser

# %%
nights = dict_tags.apply(nights_col)

# %%
nights = nights.apply(nights_cocol)

# %%
nights = nights.apply(lambda x: ''.join(x).strip("'[]',"))

# %%
nights = nights.apply(lambda x: np.nan if x == '' else x)
nights = nights.fillna(nights.mode())

# %%
nights.value_counts()
# Out:
# 1     145373
# 2     100263
# 3      72000
# 4      35748
# 5      15611
# 6       7399
# 7       5549
# 8       1910
# 9        966
# 10       663
# 11       306
# 12       217
# 14       184
# 13       174
# 15        87
# 16        38
# 17        27
# 18        24
# 19        23
# 21        19
# 20        17
# 30        10
# 27        10
# 22         8
# 28         7
# 23         6
# 26         6
# 24         5
# 25         4
# 29         3
# Name: tags, dtype: int64

# %%
hotels['nights_col'] = nights

# %%
hotels.drop(columns=['review_date', 'tags'], axis=1, inplace=True)

# %%
hotels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386803 entries, 0 to 386802
# Data columns (total 28 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   additional_number_of_scoring                386803 non-null  int64
#  1   average_score                               386803 non-null  float64
#  2   review_total_negative_word_counts           386803 non-null  int64
#  3   total_number_of_reviews                     386803 non-null  int64
#  4   review_total_positive_word_counts           386803 non-null  int64
#  5   total_number_of_reviews_reviewer_has_given  386803 non-null  int64
#  6   reviewer_score                              386803 non-null  float64
#  7   days_since_review                           386803 non-null  object
#  8   lat                                         384355 non-null  float64
#  9   lng                                         384355 non-null  float64
#  10  country_0                                   386803 non-null  int64
#  11  country_1                                   386803 non-null  int64
#  12  country_2                                   386803 non-null  int64
#  13  reviewer_nationality_0                      386803 non-null  int64
#  14  reviewer_nationality_1                      386803 non-null  int64
#  15  reviewer_nationality_2                      386803 non-null  int64
#  16  reviewer_nationality_3                      386803 non-null  int64
#  17  reviewer_nationality_4                      386803 non-null  int64
#  18  is_negative                                 386803 non-null  int64
#  19  is_positive                                 386803 non-null  int64
#  20  year                                        386803 non-null  int64
#  21  year_0                                      386803 non-null  int64
#  22  year_1                                      386803 non-null  int64
#  23  Leisure trip                                386803 non-null  int64
#  24  Couple                                      386803 non-null  int64
#  25  Solo traveler                               386803 non-null  int64
#  26  mobile submitted                            386803 non-null  int64
#  27  nights_col                                  386657 non-null  object
# dtypes: float64(4), int64(22), object(2)
# memory usage: 82.6+ MB

# %%
fill_hotels = hotels.fillna({'lat': hotels['lat'].mean(), 'lng': hotels['lng'].mean()})

# %%
hotels['days_since_review'] = hotels['days_since_review'].apply(lambda x: x.split()[0])
hotels['days_since_review'] = hotels['days_since_review'].astype('int64')

# %%
hotels['nights_col'] = hotels['nights_col'].apply(lambda x: hotels['nights_col'].mode() if x is np.nan else x)

# %%
hotels['nights_col'] = hotels['nights_col'].astype('int64')

# %%
hotels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386803 entries, 0 to 386802
# Data columns (total 28 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   additional_number_of_scoring                386803 non-null  int64
#  1   average_score                               386803 non-null  float64
#  2   review_total_negative_word_counts           386803 non-null  int64
#  3   total_number_of_reviews                     386803 non-null  int64
#  4   review_total_positive_word_counts           386803 non-null  int64
#  5   total_number_of_reviews_reviewer_has_given  386803 non-null  int64
#  6   reviewer_score                              386803 non-null  float64
#  7   days_since_review                           386803 non-null  int64
#  8   lat                                         384355 non-null  float64
#  9   lng                                         384355 non-null  float64
#  10  country_0                                   386803 non-null  int64
#  11  country_1                                   386803 non-null  int64
#  12  country_2                                   386803 non-null  int64
#  13  reviewer_nationality_0                      386803 non-null  int64
#  14  reviewer_nationality_1                      386803 non-null  int64
#  15  reviewer_nationality_2                      386803 non-null  int64
#  16  reviewer_nationality_3                      386803 non-null  int64
#  17  reviewer_nationality_4                      386803 non-null  int64
#  18  is_negative                                 386803 non-null  int64
#  19  is_positive                                 386803 non-null  int64
#  20  year                                        386803 non-null  int64
#  21  year_0                                      386803 non-null  int64
#  22  year_1                                      386803 non-null  int64
#  23  Leisure trip                                386803 non-null  int64
#  24  Couple                                      386803 non-null  int64
#  25  Solo traveler                               386803 non-null  int64
#  26  mobile submitted                            386803 non-null  int64
#  27  nights_col                                  386803 non-null  object
# dtypes: float64(4), int64(23), object(1)
# memory usage: 82.6+ MB

# %%
fig, ax = plt.subplots(figsize=(15, 15))
#ax1.set_title('Матрица корреляции')

sns.heatmap(fill_hotels.corr(), annot=True)
# Out:
# <Axes: >

# %%
fill_hotels.drop(columns=['additional_number_of_scoring', 'lat', 'lng', 'days_since_review'], axis=1, inplace=True)

# %% [markdown]
# ### Оценка значимости показателей

# %%
fill_hotels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386803 entries, 0 to 386802
# Data columns (total 24 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   average_score                               386803 non-null  float64
#  1   review_total_negative_word_counts           386803 non-null  int64
#  2   total_number_of_reviews                     386803 non-null  int64
#  3   review_total_positive_word_counts           386803 non-null  int64
#  4   total_number_of_reviews_reviewer_has_given  386803 non-null  int64
#  5   reviewer_score                              386803 non-null  float64
#  6   country_0                                   386803 non-null  int64
#  7   country_1                                   386803 non-null  int64
#  8   country_2                                   386803 non-null  int64
#  9   reviewer_nationality_0                      386803 non-null  int64
#  10  reviewer_nationality_1                      386803 non-null  int64
#  11  reviewer_nationality_2                      386803 non-null  int64
#  12  reviewer_nationality_3                      386803 non-null  int64
#  13  reviewer_nationality_4                      386803 non-null  int64
#  14  is_negative                                 386803 non-null  int64
#  15  is_positive                                 386803 non-null  int64
#  16  year                                        386803 non-null  int64
#  17  year_0                                      386803 non-null  int64
#  18  year_1                                      386803 non-null  int64
#  19  Leisure trip                                386803 non-null  int64
#  20  Couple                                      386803 non-null  int64
#  21  Solo traveler                               386803 non-null  int64
#  22  mobile submitted                            386803 non-null  int64
#  23  nights_col                                  386803 non-null  int64
# dtypes: float64(2), int64(22)
# memory usage: 70.8 MB

# %%
# непрерывные признаки
num_cols = ['total_number_of_reviews', 'review_total_negative_word_counts', 'review_total_positive_word_counts',
    'total_number_of_reviews_reviewer_has_given', 'nights_col']

# категориальные признаки
cat_cols = ['average_score', 'country_0', 'country_1', 'country_2', 'reviewer_nationality_0', 'reviewer_nationality_1',
            'reviewer_nationality_2', 'reviewer_nationality_3', 'reviewer_nationality_4', 'is_negative', 'is_positive',
            'year_0', 'year_1', 'Leisure trip', 'Couple', 'mobile submitted', 'Solo traveler']

# %%
# зададим параметры холста, название и визуализируем кривые распределения:
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(16, 21))
#ax1.set_title('Исходные распределения')
i = 0
j = 0
k = 0
for i in range(3):
    for j in range(2):
        sns.kdeplot(fill_hotels[num_cols[k]], ax=axes[i, j], label =num_cols[k])
        k +=1
        if k == 5:
            break
# kdeplot() (KDE – оценка плотности ядра) – специальный метод для графиков распределений
#sns.kdeplot(fill_hotels['total_number_of_reviews'], ax=ax1, label ='total_number_of_reviews')
#sns.kdeplot(fill_hotels['review_total_negative_word_counts'], ax=ax1, label ='review_total_negative_word_counts')
#sns.kdeplot(fill_hotels['review_total_positive_word_counts'], ax=ax1, label ='review_total_positive_word_counts')
#sns.kdeplot(fill_hotels['total_number_of_reviews_reviewer_has_given'], ax=ax1, label ='total_number_of_reviews_reviewer_has_given')
#sns.kdeplot(fill_hotels['nights_col'], ax=ax1, label ='nights_col')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df_num = fill_hotels[['total_number_of_reviews', 'review_total_negative_word_counts', 'review_total_positive_word_counts',
    'total_number_of_reviews_reviewer_has_given', 'nights_col']]
col_names = list(df_num.columns)

# %%
# инициализируем нормализатор MinMaxScaler
mm_scaler =  preprocessing.RobustScaler()

# кодируем исходный датасет
df_mm = mm_scaler.fit_transform(df_num)

# Преобразуем промежуточный датасет в полноценный датафрейм для визуализации
df_mm = pd.DataFrame(df_mm, columns=col_names)

# зададим параметры холста, название и визуализируем кривые распределения:
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(16, 21))
#ax1.set_title('Исходные распределения')
i = 0
j = 0
k = 0
for i in range(3):
    for j in range(2):
        sns.kdeplot(df_mm[num_cols[k]], ax=axes[i, j], label =num_cols[k])
        k +=1
        if k == 5:
            break
# kdeplot() (KDE – оценка плотности ядра) – специальный метод для графиков распределений
#sns.kdeplot(fill_hotels['total_number_of_reviews'], ax=ax1, label ='total_number_of_reviews')
#sns.kdeplot(fill_hotels['review_total_negative_word_counts'], ax=ax1, label ='review_total_negative_word_counts')
#sns.kdeplot(fill_hotels['review_total_positive_word_counts'], ax=ax1, label ='review_total_positive_word_counts')
#sns.kdeplot(fill_hotels['total_number_of_reviews_reviewer_has_given'], ax=ax1, label ='total_number_of_reviews_reviewer_has_given')
#sns.kdeplot(fill_hotels['nights_col'], ax=ax1, label ='nights_col')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# инициализируем стандартизатор StandardScaler
s_scaler = preprocessing.StandardScaler()

# кодируем исходный датасет
df_s = s_scaler.fit_transform(df_mm)

# Преобразуем промежуточный датасет в полноценный датафрейм для визуализации
df_s = pd.DataFrame(df_s, columns=col_names)

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(16, 21))
#ax1.set_title('Исходные распределения')
i = 0
j = 0
k = 0
for i in range(3):
    for j in range(2):
        sns.kdeplot(df_s[num_cols[k]], ax=axes[i, j], label =num_cols[k])
        k +=1
        if k == 5:
            break
# kdeplot() (KDE – оценка плотности ядра) – специальный метод для графиков распределений
#sns.kdeplot(fill_hotels['total_number_of_reviews'], ax=ax1, label ='total_number_of_reviews')
#sns.kdeplot(fill_hotels['review_total_negative_word_counts'], ax=ax1, label ='review_total_negative_word_counts')
#sns.kdeplot(fill_hotels['review_total_positive_word_counts'], ax=ax1, label ='review_total_positive_word_counts')
#sns.kdeplot(fill_hotels['total_number_of_reviews_reviewer_has_given'], ax=ax1, label ='total_number_of_reviews_reviewer_has_given')
#sns.kdeplot(fill_hotels['nights_col'], ax=ax1, label ='nights_col')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fill_hotels.describe()
# Out:
#        average_score  review_total_negative_word_counts  \
# count  386803.000000                      386803.000000
# mean        8.397231                          18.538988
# std         0.547881                          29.703369
# min         5.200000                           0.000000
# 25%         8.100000                           2.000000
# 50%         8.400000                           9.000000
# 75%         8.800000                          23.000000
# max         9.800000                         408.000000
#
#        total_number_of_reviews  review_total_positive_word_counts  \
# count            386803.000000                      386803.000000
# mean               2743.992042                          17.776985
# std                2316.457018                          21.726141
# min                  43.000000                           0.000000
# 25%                1161.000000                           5.000000
# 50%                2134.000000                          11.000000
# 75%                3613.000000                          22.000000
# max               16670.000000                         395.000000
#
#        total_number_of_reviews_reviewer_has_given  reviewer_score  \
# count                                386803.00000   386803.000000
# mean                                      7.17725        8.396906
# std                                      11.05442        1.636090
# min                                       1.00000        2.500000
# 25%                                       1.00000        7.500000
# 50%                                       3.00000        8.800000
# 75%                                       8.00000        9.600000
# max                                     355.00000       10.000000
#
#            country_0      country_1      country_2  reviewer_nationality_0  \
# count  386803.000000  386803.000000  386803.000000           386803.000000
# mean        0.264199       0.343762       0.695336                0.185234
# std         0.440906       0.474963       0.460266                0.388488
# min         0.000000       0.000000       0.000000                0.000000
# 25%         0.000000       0.000000       0.000000                0.000000
# 50%         0.000000       0.000000       1.000000                0.000000
# 75%         1.000000       1.000000       1.000000                0.000000
# max         1.000000       1.000000       1.000000                1.000000
#
#        ...    is_negative    is_positive           year         year_0  \
# count  ...  386803.000000  386803.000000  386803.000000  386803.000000
# mean   ...       0.752052       0.930494    2016.120707       0.487556
# std    ...       0.431822       0.254312       0.687740       0.499846
# min    ...       0.000000       0.000000    2015.000000       0.000000
# 25%    ...       1.000000       1.000000    2016.000000       0.000000
# 50%    ...       1.000000       1.000000    2016.000000       0.000000
# 75%    ...       1.000000       1.000000    2017.000000       1.000000
# max    ...       1.000000       1.000000    2017.000000       1.000000
#
#               year_1   Leisure trip         Couple  Solo traveler  \
# count  386803.000000  386803.000000  386803.000000  386803.000000
# mean        0.695868       0.810731       0.489169       0.210016
# std         0.460039       0.391723       0.499883       0.407320
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       1.000000       0.000000       0.000000
# 50%         1.000000       1.000000       0.000000       0.000000
# 75%         1.000000       1.000000       1.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#        mobile submitted     nights_col
# count     386803.000000  386803.000000
# mean           0.596629       2.361057
# std            0.490575       1.646407
# min            0.000000       1.000000
# 25%            0.000000       1.000000
# 50%            1.000000       2.000000
# 75%            1.000000       3.000000
# max            1.000000      30.000000
#
# [8 rows x 24 columns]

# %%
fill_hotels.drop(columns=['total_number_of_reviews', 'review_total_negative_word_counts', 'review_total_positive_word_counts',
    'total_number_of_reviews_reviewer_has_given', 'nights_col'], axis=1, inplace=True)
fill_hotels = pd.concat([fill_hotels, df_mm])

# %%
X = fill_hotels.drop(['reviewer_score'], axis = 1)  
y = fill_hotels['reviewer_score']

# %%
fill_hotels = fill_hotels.fillna(0)

# %%
fill_hotels.drop(columns=['year'], axis=1, inplace=True)

# %%
y=y.astype('int')

...
# хи-квадрат

imp_cat = pd.Series(chi2(X[cat_cols], y)[0], index=cat_cols)
imp_cat.sort_values(inplace = True)
imp_cat.plot(kind = 'barh')
# Out:
# <Axes: >

# %%
#anova

imp_num = pd.Series(f_classif(X[num_cols], y)[0], index = num_cols)
imp_num.sort_values(inplace = True)
imp_num.plot(kind = 'barh')
# Out:
# <Axes: >

# %%
fill_hotels.drop(columns=['country_0', 'country_1', 'country_2', 'reviewer_nationality_0', 'reviewer_nationality_1',
            'reviewer_nationality_2', 'reviewer_nationality_3', 'reviewer_nationality_4', 
            'year_0', 'year_1', 'Leisure trip', 'Couple', 'mobile submitted', 'Solo traveler'], axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
  
# Создаём модель  
regr = RandomForestRegressor(n_estimators=100)  
      
# Обучаем модель на тестовом наборе данных  
regr.fit(X_train, y_train)  
      
# Используем обученную модель для предсказания рейтинга отелей в тестовой выборке.  
# Предсказанные значения записываем в переменную y_pred  
y_pred = regr.predict(X_test)

# %%
# Сравниваем предсказанные значения (y_pred) с реальными (y_test), и смотрим насколько они отличаются  
# Метрика называется Mean Absolute Percentage Error (MAPE) и показывает среднюю абсолютную процентную ошибку предсказанных значений от фактических.  
print('MAPE:', metrics.mean_absolute_percentage_error(y_test, y_pred))
# Out:
# MAPE: 0.09622073021672237
